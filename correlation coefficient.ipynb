# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
y = pd.Series([1, 2, 3, 4, 3, 5, 4])
x = pd.Series([1, 2, 3, 4, 5, 6, 7])
correlation = y.corr(x)
correlation
# Out:
# 0.8603090020146067

# %%
# plotting the data
plt.scatter(x, y)

# This will fit the best line into the graph
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))
		(np.unique(x)), color='red')

# %%
import seaborn as sns

# checking correlation using heatmap
#Loading dataset
flights = sns.load_dataset("flights")

#plotting the heatmap for correlation
ax = sns.heatmap(flights.corr(), annot=True)

# %%
import seaborn as sns

# checking correlation using heatmap


#plotting the heatmap for correlation
ax = sns.heatmap(df1.corr(), annot=True)

# %%
from google.colab import files

# Use the upload widget to select and upload a CSV file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b7c5dd39-90ab-46f2-a45e-4b92873c82e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b7c5dd39-90ab-46f2-a45e-4b92873c82e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Assuming the file name is 'example.csv'
df1 = pd.read_csv('/content/correlation_smoke_lived - Iris (2).csv')

# Now you can work with the DataFrame 'df'

# %%
df1
# Out:
#    Cigarettes smoked per week  Number of years lived
# 0                          25                     63
# 1                          35                     68
# 2                          10                     72
# 3                          40                     62
# 4                          85                     65
# 5                          75                     46
# 6                          60                     51
# 7                          45                     60
# 8                          50                     55

# %%
# Rename the columns for better clarity
df = df1.rename(columns={'Cigarettes smoked per week': 'smoke', 'Number of years lived': 'lived'})

# %%
df
# Out:
#    smoke  lived
# 0     25     63
# 1     35     68
# 2     10     72
# 3     40     62
# 4     85     65
# 5     75     46
# 6     60     51
# 7     45     60
# 8     50     55

# %%
print(df['smoke'].corr(df['lived']))
# Out:
# -0.6110624935475099

# %%
correlation = df['lived'].corr(df['smoke'])
correlation

# %%
# plotting the data
plt.scatter(df['lived'] ,df['smoke'])

# %%
# Rename the columns for better clarity
df = df.rename(columns={'Cigarettes smoked per week': 'smoke', 'Number of years lived': 'lived'})

# Select the two attributes for which you want to find the correlation
smoke = df['smoke']
lived = df['lived']

# Calculate the correlation coefficient
correlation = smoke.corr(lived)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c3b24c9c68d2> in <cell line: 9>()
#       7
#       8 # Calculate the correlation coefficient
# ----> 9 correlation = smoke.corr(lived)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2758
#    2759         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2760             return nanops.nancorr(
#    2761                 this.values, other.values, method=method, min_periods=min_periods
#    2762             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
# ...

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
flights.shape
# Out:
# (144, 3)

# %%
import pandas as pd
import numpy as np

#create dataFrame with 500 rows and 3 columns
df = pd.DataFrame(index=np.arange(500), columns=np.arange(3))

#view dataFrame
df
# Out:
#        0    1    2
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# ..   ...  ...  ...
# 495  NaN  NaN  NaN
# 496  NaN  NaN  NaN
# 497  NaN  NaN  NaN
# 498  NaN  NaN  NaN
# 499  NaN  NaN  NaN
#
# [500 rows x 3 columns]

# %%
df=pd.DataFrame(flights)

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.pairplot(df)
